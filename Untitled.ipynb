# %% [markdown]
# ![](IMAGE2.png)

# %% [markdown]
# ## Bussines Problem Statement
#
# -  Location Decision :It means, if mrp is increase or decrease of products, then on which location People will it like , Tier1 ,Tir2 or Tier 3. So we have to take Decision on the basis of Visibilty and MRP, according to locations
#
# -  How to buy the stock to sell it : for that We wil check Visibilty of The type of Items according to MRP, So we can sell the stock according to that.
#
# - You can see that what type of most demandes products you can buy according to price and demand of that product and which products you can buy which comes in your product
# -  How to Find impurities in a data with visualization.
# -  How to remove that impurities wit  correct techniques.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pandas_profiling import ProfileReport

# %% [markdown]
# ## EDA and Handling Training Data

# %%
train_data=pd.read_csv("Train.csv")

# %%
train_data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
profile=ProfileReport(train_data,title='Report',explorative=True)

# %%
profile.to_widgets()
# Out:
# ...
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %% [markdown]
# ## Let's fix this Item_Fat_Content issue.

# %%
train_data['Item_Fat_Content'] = train_data['Item_Fat_Content'].map({"low fat": "Low Fat",
                                                           "Low Fat": "Low Fat",
                                                         "LF":"Low Fat",
                                                         "Regular":"Regular",
                                                         "reg":"Regular"})

# %% [markdown]
# ### Let's see first problem statement
# 1. Location Decision :It means, if mrp is increase or decrease of products, then on which location People will it like , Tier1 ,Tir2 or Tier 3. So we have to take Decision on the basis of Visibilty and MRP, according to locations

# %%
sns.scatterplot(x='Item_Visibility',y='Item_MRP',data=train_data,hue='Outlet_Location_Type')
# Out:
# <AxesSubplot:xlabel='Item_Visibility', ylabel='Item_MRP'>

# %%
sns.scatterplot(x='Item_Visibility',y='Item_MRP',data=train_data,hue='Outlet_Location_Type',legend=None)
# Out:
# <AxesSubplot:xlabel='Item_Visibility', ylabel='Item_MRP'>

# %% [markdown]
# ## Observations
#
# - If the MRP is high, the visibilty is less. of Tier 2 and Tier 3 , But tier 1 visibilty is high to  the costly product . It means if you want to sell you costly products, try to tier 1 areas , not tier 2 and tier 3.
# - Tier 2 having no visibility more than 0.17 or 0.18. ( Green Color ). means if you are working with tier 2 areas, You can sell costly products but not so much.
# - Tier 3 also have some visibilty more than Tier 2 but less than tier 1 but with less MRP.

# %% [markdown]
# ## Let's see Second Problem Statement
#
# - We wil check Visibilty of The type of Items according to MRP, So we can sell the stock according to that. (, so suppose we are opeing a shop in which , what type of stock you want to store in high amount ? . Answer is Those type of stocks which have hight mrp and high sales,

# %%
plt.figure(figsize=(15,16))
sns.scatterplot(x='Item_MRP',y='Item_Outlet_Sales', data=train_data,hue='Item_Type')
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Item_Outlet_Sales'>

# %% [markdown]
# ## Observations
#
# - Household items makes more than 12,000 of sales with high MRP.
# - At second place Snacks food makes more than 10,000  of sales.
#
# So we can increase the stock of that products in stores

# %% [markdown]
# ### Let' see third problem statement

# %% [markdown]
# You can see that what type of most demandes products you can buy according to price and demand of that product and which products you can buy which comes in your product

# %%
plt.figure(figsize=(16,10))
sns.barplot(x='Item_Type',y='Item_MRP',data=train_data)
# Out:
# <AxesSubplot:xlabel='Item_Type', ylabel='Item_MRP'>

# %% [markdown]
# ## Let's Check the Countplot of categorical Columns

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Item_Fat_Content' , data=train_data ,palette='mako')
plt.xlabel('Item_Fat_Content', fontsize=14)
plt.show()

# %%
plt.figure(figsize=(27,10))
sns.countplot(x='Item_Type' , data=train_data ,palette='summer')
plt.xlabel('Item_Type', fontsize=14)
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.countplot(x='Outlet_Type' , data=train_data )
plt.xlabel('Outlet_Type', fontsize=14)
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.countplot(x='Outlet_Location_Type' , data=train_data ,palette='twilight_shifted')
plt.xlabel('Outlet_Location_Type', fontsize=14)
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.countplot(x='Outlet_Size' , data=train_data )
plt.xlabel('Outlet_Size', fontsize=14)
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.countplot(x='Outlet_Type' , data=train_data ,palette='autumn')
plt.xlabel('Outlet_Type', fontsize=14)
plt.show()

# %% [markdown]
# ## Observation
# - Item_Fat_Content - Most items sold are low fat.
# - Item_Type - Item types that are distictly popular are fruits and vegetables and snack foods.
# - Outlet_Size - Bigmart outlets are mostly medium sized in our data.
# - Outlet_Location_Type - The most common type is Tier3.
# - Outlet_Type - By a wide margin the mode outlet type is Supermarket Type1.

# %% [markdown]
# ## Deleting Useless Columns

# %%
no_need= ['Item_Identifier','Outlet_Identifier']

# %%
train_data.drop(no_need,axis=1,inplace=True)

# %%
train_data
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0           9.300          Low Fat         0.016047                  Dairy
# 1           5.920          Regular         0.019278            Soft Drinks
# 2          17.500          Low Fat         0.016760                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519        8.380          Regular         0.046982           Baking Goods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
train_data.isnull().sum()
# Out:
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# ## Percentage of Missing Values

# %%
null_percent = ((train_data.isnull().sum() / train_data.shape[0]) * 100).sort_values(ascending = False)

# %%
null_percent
# Out:
# Outlet_Size                  28.276428
# Item_Weight                  17.165317
# Item_Fat_Content              0.000000
# Item_Visibility               0.000000
# Item_Type                     0.000000
# Item_MRP                      0.000000
# Outlet_Establishment_Year     0.000000
# Outlet_Location_Type          0.000000
# Outlet_Type                   0.000000
# Item_Outlet_Sales             0.000000
# dtype: float64

# %%
train_data.dtypes
# Out:
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %% [markdown]
# ## Filling Missing Values

# %%
train_data['Outlet_Size'].fillna(train_data['Outlet_Size'].mode()[0], inplace = True)
train_data['Item_Weight'].fillna(train_data['Item_Weight'].median(), inplace = True)

# %%
train_data.isnull().sum()
# Out:
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
numerical_columns=train_data.select_dtypes(exclude='object')

# %%
names_columns=numerical_columns.columns

# %%
for i in names_columns:
    plt.figure(figsize=(8,6))
    sns.boxplot(data=train_data,x=i)
    plt.xlabel(i, fontsize = 12)

# %%
def remove_outliers(dataframe, column):   
    Q3 = dataframe[column].quantile(0.75)
    Q1 = dataframe[column].quantile(0.25)
    IQR = Q3 - Q1
    upper = Q3 + (1.5 * IQR)
    lower = Q1 - (1.5 * IQR)
    df_no_outlier = dataframe[(dataframe[column] > lower ) & (dataframe[column] < upper)]
    return df_no_outlier

# %%
train_data = remove_outliers(train_data, "Item_Outlet_Sales")
train_data=remove_outliers(train_data,"Item_Visibility")

# %%
plt.figure(figsize = (8,8))
sns.boxplot(x = 'Item_Outlet_Sales', data = train_data);

# %%
for i in names_columns:
    plt.figure(figsize=(8,3))
    sns.distplot(train_data[i])
# Out:
# C:\Users\hp\.conda\envs\tensorflow\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hp\.conda\envs\tensorflow\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
train_data['Item_Visibility']=np.sqrt(train_data['Item_Visibility'])

# %%
sns.distplot(train_data['Item_Visibility'])
# Out:
# C:\Users\hp\.conda\envs\tensorflow\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Item_Visibility', ylabel='Density'>

# %% [markdown]
# ## Categorical Data Analysis

# %%
categorical_data=train_data.select_dtypes(include="object")

# %%
column_names=categorical_data.columns

# %%
column_names
# Out:
# Index(['Item_Fat_Content', 'Item_Type', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
for i in column_names:
    print(train_data[i].unique())
# Out:
# ['Low Fat' 'Regular']
# ['Dairy' 'Soft Drinks' 'Meat' 'Fruits and Vegetables' 'Household'
#  'Baking Goods' 'Snack Foods' 'Frozen Foods' 'Breakfast'
#  'Health and Hygiene' 'Hard Drinks' 'Canned' 'Breads' 'Starchy Foods'
#  'Others' 'Seafood']
# ['Medium' 'High' 'Small']
# ['Tier 1' 'Tier 3' 'Tier 2']
# ['Supermarket Type1' 'Supermarket Type2' 'Grocery Store'
#  'Supermarket Type3']

# %%
train_data
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0           9.300          Low Fat         0.126678                  Dairy
# 1           5.920          Regular         0.138846            Soft Drinks
# 2          17.500          Low Fat         0.129461                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.238293            Snack Foods
# 8519        8.380          Regular         0.216754           Baking Goods
# 8520       10.600          Low Fat         0.187580     Health and Hygiene
# 8521        7.210          Regular         0.381078            Snack Foods
# 8522       14.800          Low Fat         0.211845            Soft Drinks
#
# ...

# %% [markdown]
# ### creating our new column for both datasets

# %% [markdown]
# ## Outlet_Establishment_Year is quite useless as it is, making a new column with the age the new name will be Outlet_Age

# %%
train_data['Oulet_age']=train_data['Outlet_Establishment_Year'].apply(lambda year: 2021 - year)

# %%
train_data
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0           9.300          Low Fat         0.126678                  Dairy
# 1           5.920          Regular         0.138846            Soft Drinks
# 2          17.500          Low Fat         0.129461                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.238293            Snack Foods
# 8519        8.380          Regular         0.216754           Baking Goods
# 8520       10.600          Low Fat         0.187580     Health and Hygiene
# 8521        7.210          Regular         0.381078            Snack Foods
# 8522       14.800          Low Fat         0.211845            Soft Drinks
#
# ...

# %% [markdown]
# ## I want to check the following relationships with Item_Outlet_Sales:

# %% [markdown]
# - Sales per outlet
# - Sales per outlet type
# - Sales per outlet size
# - Sales per location type

# %%
plt.figure(figsize=(27,10))
sns.barplot('Item_Type' ,'Item_Outlet_Sales', data=train_data ,palette="gist_rainbow_r")
plt.xlabel('Item_Type', fontsize=14)
plt.legend()
plt.show()
# Out:
# C:\Users\hp\.conda\envs\tensorflow\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(10,5))
sns.barplot('Outlet_Type' ,'Item_Outlet_Sales', data=train_data ,palette='nipy_spectral')
plt.xlabel('Outlet_Type', fontsize=14)
plt.legend()
plt.show()
# Out:
# C:\Users\hp\.conda\envs\tensorflow\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(10,5))
sns.barplot('Outlet_Location_Type' ,'Item_Outlet_Sales', data=train_data ,palette='Spectral')
plt.xlabel('Outlet_Location_Type', fontsize=14)
plt.legend()
plt.show()
# Out:
# C:\Users\hp\.conda\envs\tensorflow\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No handles with labels found to put in legend.

# %% [markdown]
# - The difference in item types by sales is very small.
#
# -  supermarket type 3 is the most profitable and not type 1.
# - Medium and high outlet sizes are pretty much even in sales.
# - Tier 2 and 3 are almost even being the highest in sales (2 is slightly larger).

# %%
train_data
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0           9.300          Low Fat         0.126678                  Dairy
# 1           5.920          Regular         0.138846            Soft Drinks
# 2          17.500          Low Fat         0.129461                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.238293            Snack Foods
# 8519        8.380          Regular         0.216754           Baking Goods
# 8520       10.600          Low Fat         0.187580     Health and Hygiene
# 8521        7.210          Regular         0.381078            Snack Foods
# 8522       14.800          Low Fat         0.211845            Soft Drinks
#
# ...

# %%
train_data=train_data.drop(columns=['Outlet_Establishment_Year'])

# %%
train_data
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0           9.300          Low Fat         0.126678                  Dairy
# 1           5.920          Regular         0.138846            Soft Drinks
# 2          17.500          Low Fat         0.129461                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.238293            Snack Foods
# 8519        8.380          Regular         0.216754           Baking Goods
# 8520       10.600          Low Fat         0.187580     Health and Hygiene
# 8521        7.210          Regular         0.381078            Snack Foods
# 8522       14.800          Low Fat         0.211845            Soft Drinks
#
# ...

# %% [markdown]
# ## Correlation

# %%
sns.heatmap(train_data.corr() ,cmap='rocket')
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can see Item_Outlet_Sales is highly correlated with Item_MRP

# %%
from sklearn import preprocessing
L_encoder=preprocessing.LabelEncoder()
train_data['Outlet_Size']=L_encoder.fit_transform(train_data['Outlet_Size'])

# %%
train_data['Outlet_Size']
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       0
#        ..
# 8518    0
# 8519    1
# 8520    2
# 8521    1
# 8522    2
# Name: Outlet_Size, Length: 8196, dtype: int32

# %%
final_Data=pd.get_dummies(train_data,drop_first=True)

# %%
final_Data
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Size  Item_Outlet_Sales  \
# 0           9.300         0.126678  249.8092            1          3735.1380
# 1           5.920         0.138846   48.2692            1           443.4228
# 2          17.500         0.129461  141.6180            1          2097.2700
# 3          19.200         0.000000  182.0950            1           732.3800
# 4           8.930         0.000000   53.8614            0           994.7052
# ...           ...              ...       ...          ...                ...
# 8518        6.865         0.238293  214.5218            0          2778.3834
# 8519        8.380         0.216754  108.1570            1           549.2850
# 8520       10.600         0.187580   85.1224            2          1193.1136
# 8521        7.210         0.381078  103.1332            1          1845.5976
# 8522       14.800         0.211845   75.4670            2           765.6700
#
# ...

# %%
X = final_Data.drop(columns=['Item_Outlet_Sales'], axis = 1)
Y = final_Data['Item_Outlet_Sales']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25,random_state=0)

# %%
X_train
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Size  Oulet_age  \
# 6521         7.75         0.207939   92.5436            2         24
# 3965         8.01         0.265249   36.8532            1         22
# 4402        16.20         0.419733  184.0608            1         14
# 3292        17.70         0.225675  129.1678            2         17
# 3664        11.35         0.251425   88.3856            2         17
# ...           ...              ...       ...          ...        ...
# 4546        13.80         0.254107   76.2012            1         14
# 8205        10.50         0.267696  119.7098            1         14
# 5051         5.19         0.206658  197.8110            1         19
# 3394         7.75         0.288790   34.5558            1         14
# 2843        13.85         0.237986  233.8300            1         14
#
#       Item_Fat_Content_Regular  Item_Type_Breads  Item_Type_Breakfast  \
# ...

# %% [markdown]
# ## Modeling with Different Algorithms

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
predictor1 = RandomForestRegressor()
predictor1.fit(X_train,Y_train)
# Out:
# RandomForestRegressor()

# %%
predictions=predictor1.predict(X_test)
training=predictor1.predict(X_train)

# %%
predictor1.score(X_test,Y_test)
# Out:
# 0.5461135964677492

# %% [markdown]
# # xgbosst

# %%
from xgboost import XGBRegressor

# %%
Y_train
# Out:
# 6521    1701.7848
# 3965     755.0172
# 4402    2021.3688
# 3292    1780.3492
# 3664    1318.2840
#           ...
# 4546    1669.8264
# 8205    2410.1960
# 5051    2946.1650
# 3394     441.4254
# 2843    2796.3600
# Name: Item_Outlet_Sales, Length: 6147, dtype: float64

# %%
model2=XGBRegressor()
model2.fit(X_train,Y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=8, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
predictions=model2.predict(X_test)
training=model2.predict(X_train)

# %%
model2.score(X_test,Y_test)
# Out:
# 0.5093196343845607

# %% [markdown]
# ## Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
model3=GradientBoostingRegressor()
model3.fit(X_train,Y_train)
# Out:
# GradientBoostingRegressor()

# %%
prediction3=model3.predict(X_test)
test_pred=model3.predict(X_train)

# %%
model3.score(X_test,Y_test)
# Out:
# 0.5837693591055838

# %% [markdown]
# ## Lasso

# %%
from sklearn.linear_model import Lasso
ls = Lasso(alpha = 0.01)
ls.fit(X_train, Y_train)
# Out:
# Lasso(alpha=0.01)

# %%
predictions = ls.predict(X_test)

# %%
ls.score(X_test, Y_test)
# Out:
# 0.5580050866072488

# %%
import pickle
file=open('random_forest.pkl','wb')
pickle.dump(predictor1,file)
